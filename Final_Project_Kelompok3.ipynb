# %%
import pandas as pd
import numpy as np
#Transformasi data
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("C:/Users/Acer/Downloads//DATA_COVID_1.csv")
df
# Out:
#          Unnamed: 0  USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  PNEUMONIA  AGE  \
# 0                 0      2             1    1             1          1   65
# 1                 1      2             1    2             1          1   72
# 2                 2      2             1    2             2          2   55
# 3                 3      2             1    1             1          2   53
# 4                 4      2             1    2             1          2   68
# ...             ...    ...           ...  ...           ...        ...  ...
# 1017104     1048570      2            13    2             1          2   40
# 1017105     1048571      1            13    2             2          2   51
# 1017106     1048572      2            13    2             1          2   55
# 1017107     1048573      2            13    2             1          2   28
# 1017108     1048574      2            13    2             1          2   52
#
# ...

# %%
X = df.drop("DEATH", axis=1).values
y = df["DEATH"].values

# %%
from imblearn.over_sampling import RandomOverSampler,SMOTE

SMOTE = SMOTE(random_state=0)
X, y = SMOTE.fit_resample(X,y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
#KLASIFIKASI DENGAN KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
KNN = KNeighborsClassifier()

KNN.fit(X_train, y_train)
y_pred6 = KNN.predict(X_test)
score6 = metrics.accuracy_score(y_test, y_pred6)
print("Akurasi dengan menggunakan KNN: ", score6)
# Out:
# Akurasi dengan menggunakan KNN:  0.9789786612782074

# %%
from sklearn.neighbors import KNeighborsClassifier
import pickle


# Pickle the KNN model
filename = "KNN_model.pkl"
pickle.dump(knn, open(filename, "wb"))

# %%
# Pickle Scaler model
filename="Scaler_model.pkl"
pickle.dump(scaler, open(filename, "wb"))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
rfc = RandomForestClassifier()

rfc.fit(X_train, y_train)
y_pred8 = rfc.predict(X_test)
score8 = metrics.accuracy_score(y_test, y_pred8)

# %%
print("Akurasi dengan menggunakan RFC: ", score8)
# Out:
# Akurasi dengan menggunakan KNN:  0.9993811030119654

# %%
import pickle
fillname1="RFC_modelkematian.pkl"
pickle.dump(rfc, open(fillname1,"wb"))

# %%
#Klasifikasi dengan Decision Tree
from sklearn.tree import DecisionTreeClassifier
DTR = DecisionTreeClassifier()

DTR.fit(X_train, y_train)
y_pred7 = DTR.predict(X_test)
score7 = metrics.accuracy_score(y_test, y_pred7)
print("Akurasi dengan menggunakan Decision Tree: ", score7)
# Out:
# Akurasi dengan menggunakan Decision Tree:  0.9999656168339981

# %%
print("Akurasi dengan menggunakan DTR: ", score7)
# Out:
# Akurasi dengan menggunakan DTR:  0.9999656168339981

# %%
import pickle
fillname1="DTR_modelkematian.pkl"
pickle.dump(DTR, open(fillname1,"wb"))
